# %% [markdown]
# # 建立文字處理的基礎工具

# %%
# 資料庫
group_name = "getNewsData.js"  # 啟動程式
db_path = r'..\ford-news-source.db'  # 資料庫路徑

# %%
from datetime import datetime, timezone

# %%
# 國際時間
def get_utc_time():
    utc_time = datetime.now(timezone.utc)
    return utc_time.strftime("%Y%m%d%H%M%S")

# 客製化String
def trim_string(string):
    return string.strip()

# %% [markdown]
# ## 資料庫與資料

# %%
import sqlite3

# %% [markdown]
# ### 資料庫- 針對Ford news keyword做蒐集用

# %%
# 連接到 SQLite 資料庫
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# 建立資料表
cursor.execute('''
    CREATE TABLE IF NOT EXISTS DATA_KEYWORDS (
        ID INTEGER PRIMARY KEY AUTOINCREMENT,
        KEYWORD TEXT,
        TYPE TEXT,
        VECTORS_BART_ZH BLOB,
        NOTE TEXT,
        DATE INTEGER
    )
''')

conn.commit()

print('完成 DATA_KEYWORDS 資料表建置')

conn.close()
# Out:
# 完成 DATA_KEYWORDS 資料表建置

# %% [markdown]
# ### 資料庫-現有資料讀取

# %%
# 連資料庫
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# 從原始資料庫中擷取關鍵字
original_keywords =[]

# 建立資料表
cursor.execute(''' SELECT NEWS_KEYWORDS FROM DATA_NEWS WHERE  COALESCE(NEWS_KEYWORDS, '') !='' ''')

original_keywords = cursor.fetchall()

print(f'取出 {len(original_keywords)} 筆')
print(f'取出 {original_keywords} ')

conn.commit()
conn.close()

# %%
# %pip install torch --upgrade
# %pip install spacy --upgrade
# %pip install transformers --upgrade
# %pip install spacy-transformers --upgrade
# %python -m spacy download zh_core_web_sm

# %%
# %pip install transformers --upgrade

# %%
# %pip install -u huggingface_hub
# %pip show huggingface-hub

# %%
# 登入
# https://huggingface.co/settings/tokens
# !huggingface-cli login --token　已遮蔽

# %%
# 確認是否登入
# !huggingface-cli whoami

# %%
# 確認版本
import transformers
print(transformers.__version__)

# %%
import spacy
import sqlite3
import torch
from transformers import AutoTokenizer, AutoModel

bert_case = "bert-base-chinese"

def load_spacy_model():
    # 檢查模型是否可用
    nlp = spacy.load('zh_core_web_sm')
    if nlp is not None:
        print("SpaCy 模型載入成功")
    else:
        print("SpaCy 模型載入失敗")

    return nlp

def load_tokenizer_model():
    return AutoTokenizer.from_pretrained(bert_case)


def load_bert_model():
    return AutoModel.from_pretrained(bert_case)


def trim_strings(words):
    # 清除前後空白與空值    
    trimmed_words = [word.strip() for word in words if word.strip()]
    return trimmed_words

def remove_duplicates(lst):
    return list(set(lst))

def insert_new_keywords_to_db(conn, nlp, keywords):
    print('----- insert_new_keywords_to_db ----- S')
    for keyword in keywords:
        doc = nlp(keyword)
        if len(doc) > 0:
            keyword_type = doc[0].pos_
        else:
            keyword_type = "Unknown"

        cursor = conn.cursor()
        cursor.execute('INSERT INTO DATA_KEYWORDS (KEYWORD, TYPE, DATE) VALUES (?, ?, ?)',
                       (keyword, keyword_type, get_utc_time()))
        print(f'資料庫新增：{keyword} ')

    print('----- insert_new_keywords_to_db ----- E')


def update_words_embeddings_to_db(conn, tokenizer, model, words):

    print('----- update_words_embeddings_to_db ----- S')
    for keyword in words:
        # 將句子轉換為模型所需的輸入張量
        input_ids = tokenizer.encode(
            keyword, padding=True, truncation=True, return_tensors="pt", max_length=512)
        inputs = torch.tensor(input_ids)

        # 獲取該句子的嵌入向量
        with torch.no_grad():
            embedding = model(inputs)[0][:, 0, :]  # 取得 [CLS] token 的嵌入向量
            embedding_bytes = embedding.detach().numpy().tobytes()

        # 檢查資料庫中是否已存在相同的句子
        cursor = conn.execute(
            "SELECT id FROM DATA_KEYWORDS WHERE KEYWORD = ?", (keyword,))
        row = cursor.fetchone()
        if row is not None:
            # 若已存在，使用 UPDATE 指令進行更新
            conn.execute(
                "UPDATE DATA_KEYWORDS SET VECTORS_BART_ZH = ? WHERE KEYWORD = ?", (embedding_bytes, keyword))
            print(f'更新：{keyword}')
        else:
            # 若不存在，使用 INSERT 指令進行插入
            conn.execute(
                "INSERT INTO DATA_KEYWORDS (VECTORS_BART_ZH, KEYWORD) VALUES (?, ?)", (embedding_bytes, keyword))
            print(f'新增：{keyword}')

    print('----- update_words_embeddings_to_db ----- E')


def extract_unique_words(data):
    print('----- extract_unique_words ----- S')
    # 將SQL撈出的,分隔字串合併再一起
    # 例如
    # 取出： [('順德,Tesla,電動,充電站,產品,快充',), ('美國,電動,OPTIMAL,車王電,電動巴士',), ('聯嘉,營收',)]
    # 改成: ['充電站', '電動巴士', '車王電', '營收', '快充', '聯嘉', '順德', '產品', 'OPTIMAL', 'Tesla', '電動', '美國']
    words = []
    for row in data:
        keyword_str = row[0]
        keywords = keyword_str.split(',')
        words.extend(keywords)

    clean_words = trim_strings(words)
    unique_words = remove_duplicates(clean_words)

    print(f'整理後資料 {len(unique_words)} 筆')
    print('----- extract_unique_words ----- E')
    return unique_words


def get_news_original_keywords(conn):
    print('----- get_news_original_keywords ----- S')
    # TODO: 未來要增加處理條件
    # 從原始的新聞資料庫中擷取關鍵字，新聞資料的關鍵字都是尚未處理項目，每個array的一塊可能是數個資料串起來
    original_keywords = []

    # 建立資料表
    cursor = conn.cursor()
    cursor.execute(
        ''' SELECT NEWS_KEYWORDS FROM DATA_NEWS WHERE  COALESCE(NEWS_KEYWORDS, '') !='' ''')

    original_keywords = cursor.fetchall()

    print(f'取出 {len(original_keywords)} 筆')
    print('----- get_news_original_keywords ----- E')
    return original_keywords


def exclude_existing_data(conn, words):
    print('----- exclude_existing_data ----- S')
    # 篩選掉已經存在於資料庫中的字
    # TODO: 以後可以讓SQL是動態的
    existing_words = []
    cursor = conn.cursor()
    cursor.execute('SELECT KEYWORD FROM DATA_KEYWORDS')
    for row in cursor.fetchall():
        existing_words.append(row[0])

    filtered_words = [word for word in words if word not in existing_words]
    print(f'預期輸入{len(words)}筆，既有資料庫{len(existing_words)}，篩選後 {len(filtered_words)} 筆')
    print('----- exclude_existing_data ----- E')
    return filtered_words



def process_and_update_keywords(db_path):
    conn = None
    try:
        # 連接到 SQLite 資料庫
        conn = sqlite3.connect(db_path)

        # 載入 SpaCy 模型
        nlp = load_spacy_model()

        # 載入 tokenizer 和 BERT 模型
        tokenizer = load_tokenizer_model()
        model = load_bert_model()

        # 取得資料
        news_original_keywords = get_news_original_keywords(conn)
        unique_keywords = extract_unique_words(news_original_keywords)

        # 拆分並整理關鍵字
        # processed_keywords = process_keywords(original_keywords)
        print(f'DATA_NEWS 目前有 {len(unique_keywords)} 筆關鍵字')

        # 篩選掉已經存在於資料庫中的關鍵字 (注意，後面處理資料以Array為核心)
        new_keywords = exclude_existing_data(conn, unique_keywords)
        print(f'排除現有DATA_KEYWORDS，預計新增 {len(new_keywords)} 筆關鍵字')

        # 將整理後的關鍵字儲存到資料庫中
        insert_new_keywords_to_db(conn, nlp, new_keywords)

        # 更新嵌入向量到資料庫中
        update_words_embeddings_to_db(conn, tokenizer, model, new_keywords)

        # 儲存變更
        conn.commit()
    except Exception as e:
        print(f"發生錯誤：{str(e)}")
        print(f"一切儲存已經終止")
    finally:
        if conn is not None:
            conn.close()


# 使用範例
process_and_update_keywords(db_path)
# Out:
# SpaCy 模型載入成功
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ----- get_news_original_keywords ----- S
# 取出 751 筆
# ----- get_news_original_keywords ----- E
# ----- extract_unique_words ----- S
# 整理後資料 1278 筆
# ----- extract_unique_words ----- E
# DATA_NEWS 目前有 1278 筆關鍵字
# ----- exclude_existing_data ----- S
# 預期輸入1278筆，既有資料庫0，篩選後 1278 筆
# ----- exclude_existing_data ----- E
# 排除現有DATA_KEYWORDS，預計新增 1278 筆關鍵字
# ----- insert_new_keywords_to_db ----- S
# 資料庫新增：Lightning
# 資料庫新增：市占
# 資料庫新增：本田
# 資料庫新增：社群
# 資料庫新增：德國
# 資料庫新增：type:post
# 資料庫新增：訪中
# 資料庫新增：現代汽車
# 資料庫新增：car
# 資料庫新增：英國復古跑車
# 資料庫新增：日本
# 資料庫新增：菜單
# 資料庫新增：7人座
# 資料庫新增：寶馬
# 資料庫新增：電動馬達
# 資料庫新增：J1772
# 資料庫新增：BuyCarTv
# 資料庫新增：紅杉
# 資料庫新增：市佔率
# 資料庫新增：即時新聞
# 資料庫新增：嘉泥
# 資料庫新增：休旅車
# 資料庫新增：密西根州
# 資料庫新增：X
# 資料庫新增：wagon
# 資料庫新增：旅行車
# 資料庫新增：一次
# 資料庫新增：Crown
# 資料庫新增：AC
# 資料庫新增：Mitsubishi 歐洲 推出 全新 Colt 台灣 國產化 引進
# 資料庫新增：撞擊
# 資料庫新增：夏季
# 資料庫新增：RTR
# 資料庫新增：TRD
# 資料庫新增：報稅
# 資料庫新增：Chevrolet 推出 最後 一款 第六代 Camaro 紀念版 Panther
# 資料庫新增：嘉偉
# 資料庫新增：video
# 資料庫新增：Formula 1
# 資料庫新增：Roadster
# 資料庫新增：優惠
# 資料庫新增：ARTC
# 資料庫新增：體質
# 資料庫新增：長期
# 資料庫新增：Fisker
# 資料庫新增：智慧駕駛
# 資料庫新增：Ferrari
# 資料庫新增：信義新天地
# 資料庫新增：台北國際車用電子展
# 資料庫新增：美銀證券
# 資料庫新增：FORD TRANSIT XJ220
# 資料庫新增：車廠
# 資料庫新增：車
# 資料庫新增：做空機構
# 資料庫新增：Kg
# 資料庫新增：評級
# 資料庫新增：Pro
# 資料庫新增：VOLVO
# 資料庫新增：Volkswagen T-Roc
# 資料庫新增：Focus Wagon
# 資料庫新增：6000
# 資料庫新增：品牌
# 資料庫新增：suv
# 資料庫新增：大改款
# 資料庫新增：轉虧為盈
# 資料庫新增：WildtrakX
# 資料庫新增：美規
# 資料庫新增：CCS2
# 資料庫新增：Drag
# 資料庫新增：經濟衰退
# 資料庫新增：重型機車
# 資料庫新增：引擎
# 資料庫新增：CHAdeMO
# 資料庫新增：2024 Ford Mustang RTR Spec 2
# 資料庫新增：半導體
# 資料庫新增：影音系統
# 資料庫新增：2024年
# 資料庫新增：Opel
# 資料庫新增：採購副總
# 資料庫新增：投資人
# 資料庫新增：試車頻道
# 資料庫新增：蝙蝠俠機車
# 資料庫新增：Wards
# 資料庫新增：WRX Wagon
# 資料庫新增：科技類股
# 資料庫新增：Capstone
# 資料庫新增：Kuga
# 資料庫新增：空間
# 資料庫新增：三菱
# 資料庫新增：HR-V
# 資料庫新增：銷售
# 資料庫新增：專題報導
# 資料庫新增：女性墮胎權
# 資料庫新增：cat:新聞
# 資料庫新增：自行車
# 資料庫新增：Ford 正式 發佈 Mustang GT3 賽車 將於 2024 參加  Le Mans  24 小時 耐力賽
# 資料庫新增：電動車市
# 資料庫新增：地方新聞
# 資料庫新增：股價
# 資料庫新增：CX-90
# 資料庫新增：國運
# 資料庫新增：sports
# 資料庫新增：特斯拉 Cybertruck 照片 外洩 內裝 設計 細節 曝光
# 資料庫新增：Corsa
# 資料庫新增：法利
# 資料庫新增：烏俄戰爭
# 資料庫新增：Pick up
# 資料庫新增：試車影片
# 資料庫新增：薪資
# 資料庫新增：農業
# 資料庫新增：5月
# 資料庫新增：Renault
# 資料庫新增：人選
# 資料庫新增：Shell
# 資料庫新增：短缺
# 資料庫新增：汽車新聞
# 資料庫新增：紐西蘭
# 資料庫新增：Mustang Mach-E
# 資料庫新增：Hennessey
# 資料庫新增：柯有謙
# 資料庫新增：巨大
# 資料庫新增：補助
# 資料庫新增：進擊的巨人
# 資料庫新增：系統
# 資料庫新增：ModelX
# 資料庫新增：Tucson
# 資料庫新增：英業達
# 資料庫新增：撞測
# 資料庫新增：車型
# 資料庫新增：鄭顯聰
# 資料庫新增：EV
# 資料庫新增：報告
# 資料庫新增：日系
# 資料庫新增：做空
# 資料庫新增：娛樂
# 資料庫新增：焦慮
# 資料庫新增：規格
# 資料庫新增：2024
# 資料庫新增：六缸引擎
# 資料庫新增：馬丁
# 資料庫新增：Bolide
# 資料庫新增：Y
# 資料庫新增：四驅
# 資料庫新增：大眾
# 資料庫新增：法拉利
# 資料庫新增：配備
# 資料庫新增：電動休旅車
# 資料庫新增：殼牌
# 資料庫新增：瘦子
# 資料庫新增：Stormtrak
# 資料庫新增：Golf
# 資料庫新增：耐落
# 資料庫新增：順德
# 資料庫新增：儀表
# 資料庫新增：凱銳
# 資料庫新增：買車
# 資料庫新增：車訊
# 資料庫新增：消費者報告
# 資料庫新增：COROLLA
# 資料庫新增：碳中和
# 資料庫新增：全球
# 資料庫新增：MIH
# 資料庫新增：銷量
# 資料庫新增：聯準會
# 資料庫新增：MG
# 資料庫新增：XC40
# 資料庫新增：ID.7
# 資料庫新增：車王電子
# 資料庫新增：群創
# 資料庫新增：中國大陸
# 資料庫新增：Classic
# 資料庫新增：黎方國
# 資料庫新增：自動駕駛
# 資料庫新增：小七車觀點
# 資料庫新增：ESG
# 資料庫新增：TCar
# 資料庫新增：accident
# 資料庫新增：汽車討論
# 資料庫新增：VI
# 資料庫新增：Explorer
# 資料庫新增：車後座娛樂
# 資料庫新增：六度
# 資料庫新增：歐盟
# 資料庫新增：周四
# 資料庫新增：比爾
# 資料庫新增：交通
# 資料庫新增：銷售冠軍
# 資料庫新增：墮胎
# 資料庫新增：WGS矩陣分析
# 資料庫新增：進口
# 資料庫新增：小型
# 資料庫新增：FIA
# 資料庫新增：中堅企業
# 資料庫新增：第一季
# 資料庫新增：曼谷車展
# 資料庫新增：旅遊
# 資料庫新增：Ford Focus Active
# 資料庫新增：中型休旅
# 資料庫新增：套件
# 資料庫新增：Model X
# 資料庫新增：名單
# 資料庫新增：VAG
# 資料庫新增：財報
# 資料庫新增：指數基金
# 資料庫新增：福特
# 資料庫新增：蔚小理
# 資料庫新增：短軸
# 資料庫新增：Valiance
# 資料庫新增：露營
# 資料庫新增：Model C
# 資料庫新增：SAE
# 資料庫新增：經濟
# 資料庫新增：澳洲
# 資料庫新增：iPhone
# 資料庫新增：福特六和
# 資料庫新增：SYND
# 資料庫新增：Dodge
# 資料庫新增：醫師
# 資料庫新增：超級
# 資料庫新增：台電
# 資料庫新增：數位
# 資料庫新增：廢氣排放
# 資料庫新增：Mercedes
# 資料庫新增：省油
# 資料庫新增：紐約市
# 資料庫新增：電競
# 資料庫新增：PORSCHE VISION RENNDIENST
# 資料庫新增：企業
# 資料庫新增：電動車銷售
# 資料庫新增：Top Gear
# 資料庫新增：政治
# 資料庫新增：優勢
# 資料庫新增：扣留
# 資料庫新增：V8引擎
# 資料庫新增：racing
# 資料庫新增：Berlingo短軸
# 資料庫新增：柯有倫
# 資料庫新增：Sedan
# 資料庫新增：兩輪誌
# 資料庫新增：機車
# 資料庫新增：Ford Supervan
# 資料庫新增：Honda Fit
# 資料庫新增：ID3
# 資料庫新增：軟頂
# 資料庫新增：ID
# 資料庫新增：南陽實業
# 資料庫新增：麥拉倫
# 資料庫新增：Lamborghini
# 資料庫新增：台灣本田
# 資料庫新增：輪胎
# 資料庫新增：因應
# 資料庫新增：餐廳
# 資料庫新增：聯嘉
# 資料庫新增：塔科馬
# 資料庫新增：疲勞
# 資料庫新增：壓力
# 資料庫新增：Yahoo
# 資料庫新增：Bilstein
# 資料庫新增：高階
# 資料庫新增：U6
# 資料庫新增：line
# 資料庫新增：市占率
# 資料庫新增：運動休旅
# 資料庫新增：生產
# 資料庫新增：太陽能
# 資料庫新增：敞篷
# 資料庫新增：毛利率
# 資料庫新增：渦輪增壓
# 資料庫新增：外長
# 資料庫新增：預估
# 資料庫新增：插電式油電
# 資料庫新增：Super
# 資料庫新增：新聞照片
# 資料庫新增：Electric
# 資料庫新增：試車
# 資料庫新增：賽車
# 資料庫新增：LED
# 資料庫新增：標準
# 資料庫新增：員工
# 資料庫新增：HS
# 資料庫新增：分析
# 資料庫新增：侯友宜
# 資料庫新增：Ford Performance
# 資料庫新增：Leaf
# 資料庫新增：特斯拉股票
# 資料庫新增：稅收
# 資料庫新增：抵免
# 資料庫新增：體系
# 資料庫新增：下滑
# 資料庫新增：Car
# 資料庫新增：再降
# 資料庫新增：CX-70
# 資料庫新增：電動汽車
# 資料庫新增：Benz
# 資料庫新增：Jeep
# 資料庫新增：華碩
# 資料庫新增：高端
# 資料庫新增：西方
# 資料庫新增：華爾街日報
# 資料庫新增：automobiles
# 資料庫新增：Peugeot 806 Procar
# 資料庫新增：KUGA
# 資料庫新增：趨勢
# 資料庫新增：電網
# 資料庫新增：華友
# 資料庫新增：Triton
# 資料庫新增：教育
# 資料庫新增：知情人士
# 資料庫新增：北美
# 資料庫新增：TOYOTA
# 資料庫新增：3
# 資料庫新增：成長
# 資料庫新增：28
# 資料庫新增：10年
# 資料庫新增：astrA
# 資料庫新增：跨境電商
# 資料庫新增：Sandero
# 資料庫新增：Bugatti
# 資料庫新增：Bronco
# 資料庫新增：買氣
# 資料庫新增：南韓
# 資料庫新增：購車
# 資料庫新增：Cross
# 資料庫新增：林鎮
# 資料庫新增：零件
# 資料庫新增：MINI
# 資料庫新增：特斯拉股價
# 資料庫新增：飛宏
# 資料庫新增：減碳目標
# 資料庫新增：標指
# 資料庫新增：雪地
# 資料庫新增：黃金
# 資料庫新增：貨卡
# 資料庫新增：4缸
# 資料庫新增：五菱宏光
# 資料庫新增：聯邦快遞
# 資料庫新增：Cybertruck
# 資料庫新增：全球電動車
# 資料庫新增：汽油
# 資料庫新增：泰國
# 資料庫新增：VW
# 資料庫新增：提案
# 資料庫新增：賽道
# 資料庫新增：礦業
# 資料庫新增：持有
# 資料庫新增：會面
# 資料庫新增：露營車
# 資料庫新增：上海車展
# 資料庫新增：Dynamics
# 資料庫新增：地球
# 資料庫新增：LCV
# 資料庫新增：Elon Musk
# 資料庫新增：Andy
# 資料庫新增：MORGAN 英國
# 資料庫新增：通用電動車
# 資料庫新增：國事訪問
# 資料庫新增：貸款
# 資料庫新增：老爹
# 資料庫新增：展覽
# 資料庫新增：新商機
# 資料庫新增：未平倉
# 資料庫新增：Berlingo
# 資料庫新增：小三
# 資料庫新增：馬來西亞
# 資料庫新增：Mustang
# 資料庫新增：Volkswagen Golf
# 資料庫新增：ai
# 資料庫新增：供應鏈
# 資料庫新增：碳排放量
# 資料庫新增：節能
# 資料庫新增：備用電池
# 資料庫新增：Consumer reports
# 資料庫新增：巴西
# 資料庫新增：福特 推出 全新 野馬 GT4 賽車 全球 賽車 愛好者 提供 更多 選擇
# 資料庫新增：西亞
# 資料庫新增：充電
# 資料庫新增：車用晶片
# 資料庫新增：價格戰
# 資料庫新增：品質
# 資料庫新增：售價
# 資料庫新增：疫情
# 資料庫新增：Luxgen U6 Neo
# 資料庫新增：七人座
# 資料庫新增：新車
# 資料庫新增：車評
# 資料庫新增：標普
# 資料庫新增：拜登
# 資料庫新增：再生能源
# 資料庫新增：Hatch
# 資料庫新增：快充
# 資料庫新增：環保
# 資料庫新增：俄羅斯
# 資料庫新增：Bentley
# 資料庫新增：Mk
# 資料庫新增：測試
# 資料庫新增：經歷
# 資料庫新增：朱嘉偉
# 資料庫新增：東協
# 資料庫新增：MustangMach
# 資料庫新增：業績
# 資料庫新增：六福
# 資料庫新增：Heritage
# 資料庫新增：重返台灣 ！拼交車速度  6/7發表 最快6月底交車 Opel The New Astra 正式曝光！
# 資料庫新增：Tacoma
# 資料庫新增：執行長
# 資料庫新增：福特 特斯拉 達成 充電 合作 放棄 CCS1 採用 NACS
# 資料庫新增：服務
# 資料庫新增：高速公路
# 資料庫新增：影視
# 資料庫新增：IPO
# 資料庫新增：校車
# 資料庫新增：2019
# 資料庫新增：Touran
# 資料庫新增：道瓊工業指數
# 資料庫新增：配息
# 資料庫新增：週休二日
# 資料庫新增：車艙
# 資料庫新增：Line
# 資料庫新增：關鍵原料
# 資料庫新增：台灣樂高
# 資料庫新增：FORD 歐洲/福特
# 資料庫新增：V60
# 資料庫新增：交通部
# 資料庫新增：American
# 資料庫新增：Ford Kuga
# 資料庫新增：雜誌
# 資料庫新增：領牌
# 資料庫新增：TESLA
# 資料庫新增：Suzuki
# 資料庫新增：徐榛蔚
# 資料庫新增：印度
# 資料庫新增：電動車車主
# 資料庫新增：摩托車
# 資料庫新增：車用面板
# 資料庫新增：JD Power
# 資料庫新增：車市
# 資料庫新增：基金
# 資料庫新增：改款
# 資料庫新增：HONDA
# 資料庫新增：後續營運
# 資料庫新增：跨界休旅
# 資料庫新增：預測
# 資料庫新增：中國電動車
# 資料庫新增：國際
# 資料庫新增：應用材料
# 資料庫新增：muscle car
# 資料庫新增：年齡
# 資料庫新增：Hyundai
# 資料庫新增：F1
# 資料庫新增：持股
# 資料庫新增：Volvo XC60試駕
# 資料庫新增：台北
# 資料庫新增：生活
# 資料庫新增：台積電
# 資料庫新增：新一代
# 資料庫新增：電動車充電
# 資料庫新增：YARIS
# 資料庫新增：海外試駕
# 資料庫新增：現代
# 資料庫新增：庫存
# 資料庫新增：純電動車
# 資料庫新增：Lexus LM
# 資料庫新增：布林肯
# 資料庫新增：Hilux
# 資料庫新增：中國
# 資料庫新增：ID.3
# 資料庫新增：電動自行車
# 資料庫新增：Mondeo
# 資料庫新增：Aston Martin 110th Anniversary
# 資料庫新增：HYUNDAI IMAX N
# 資料庫新增：Genesis
# 資料庫新增：2023派克峰爬山賽 Ford、Alpine、Radford佳績出爐
# 資料庫新增：鎳礦
# 資料庫新增：超跑
# 資料庫新增：中華汽車
# 資料庫新增：Tremor
# 資料庫新增：銀行業
# 資料庫新增：礦商
# 資料庫新增：TOYOTA  2024 全新 Tacoma 首款 混合 動力 中型 皮卡
# 資料庫新增：跑車
# 資料庫新增：汽車價格
# 資料庫新增：消基會
# 資料庫新增：編輯精選
# 資料庫新增：太平島
# 資料庫新增：墨西哥
# 資料庫新增：改裝
# 資料庫新增：電動巴士
# 資料庫新增：沃爾瑪
# 資料庫新增：秦剛
# 資料庫新增：F-150
# 資料庫新增：特定
# 資料庫新增：TSS 3.0
# 資料庫新增：Taiwan
# 資料庫新增：Mercedes-AMG
# 資料庫新增：百度
# 資料庫新增：Google
# 資料庫新增：Ford Mustang
# 資料庫新增：Astra
# 資料庫新增：違反
# 資料庫新增：賓士
# 資料庫新增：自由開講
# 資料庫新增：人權問題
# 資料庫新增：瑪莎拉帝
# 資料庫新增：EV Pro
# 資料庫新增：Ford 準備  歐洲 推出 純電 Tourneo 車系 E-Tourneo Courier Tourneo
# 資料庫新增：ChargePoint
# 資料庫新增：中國供應鏈
# 資料庫新增：4月
# 資料庫新增：IEA
# 資料庫新增：focus
# 資料庫新增：Focus
# 資料庫新增：最新
# 資料庫新增：汽車市場
# 資料庫新增：兩年
# 資料庫新增：APEC
# 資料庫新增：PChome Online 新聞提供最新社會新聞、人氣社會新聞、社會專題、社會新聞照片、社會新聞影片
# 資料庫新增：果粉
# 資料庫新增：亞馬遜
# 資料庫新增：Model
# 資料庫新增：柴油
# 資料庫新增：蝙蝠俠
# 資料庫新增：Ferrari Daytona SP3
# 資料庫新增：今日新聞
# 資料庫新增：SYNC4
# 資料庫新增：宣德
# 資料庫新增：小改款
# 資料庫新增：Ford Mustang GT3
# 資料庫新增：GT3
# 資料庫新增：BEV
# 資料庫新增：vr
# 資料庫新增：WEC
# 資料庫新增：車展
# 資料庫新增：Hyundai Staria
# 資料庫新增：4驅
# 資料庫新增：雲端服務
# 資料庫新增：小糸
# 資料庫新增：電影
# 資料庫新增：Land Rover
# 資料庫新增：V6渦輪引擎
# 資料庫新增：保養
# 資料庫新增：AMG
# 資料庫新增：惠普
# 資料庫新增：樂高
# 資料庫新增：雙方
# 資料庫新增：Formula Drift
# 資料庫新增：車企
# 資料庫新增：皮卡
# 資料庫新增：富邦投信
# 資料庫新增：合作
# 資料庫新增：智能
# 資料庫新增：Maserati
# 資料庫新增：Ford Ranger
# 資料庫新增：ID7
# 資料庫新增：Model 3
# 資料庫新增：Porsche
# 資料庫新增：瑞銀
# 資料庫新增：大量
# 資料庫新增：Mini
# 資料庫新增：供給
# 資料庫新增：加拿大
# 資料庫新增：和泰車
# 資料庫新增：Mazda
# 資料庫新增：特仕車
# 資料庫新增：R34
# 資料庫新增：評比
# 資料庫新增：ces
# 資料庫新增：建設
# 資料庫新增：Ram
# 資料庫新增：打卡
# 資料庫新增：XC90
# 資料庫新增：機械增壓
# 資料庫新增：Audi S3 Sedan 2.0 TFSI quattro
# 資料庫新增：Crossover
# 資料庫新增：大陸
# 資料庫新增：上海
# 資料庫新增：長安福特
# 資料庫新增：華友鈷業
# 資料庫新增：渦輪
# 資料庫新增：汽車電子
# 資料庫新增：精確
# 資料庫新增：Jeepster
# 資料庫新增：FORD
# 資料庫新增：禮來
# 資料庫新增：Superb
# 資料庫新增：火山
# 資料庫新增：Red Bull
# 資料庫新增：獲得
# 資料庫新增：龍頭
# 資料庫新增：成本
# 資料庫新增：速命道
# 資料庫新增：採購
# 資料庫新增：折價
# 資料庫新增：Corolla
# 資料庫新增：ST
# 資料庫新增：EDGE
# 資料庫新增：商用車市場
# 資料庫新增：Tesla Model Y
# 資料庫新增：影音
# 資料庫新增：ID.4
# 資料庫新增：新車銷量
# 資料庫新增：敞篷跑車
# 資料庫新增：CPI
# 資料庫新增：Ford Mondeo
# 資料庫新增：旅遊業
# 資料庫新增：車控系統
# 資料庫新增：分析師
# 資料庫新增：票價
# 資料庫新增：Kia
# 資料庫新增：簽訂
# 資料庫新增：扣件
# 資料庫新增：電競筆電
# 資料庫新增：華城
# 資料庫新增：IC
# 資料庫新增：Sport
# 資料庫新增：LG
# 資料庫新增：越野機車
# 資料庫新增：劉揚偉
# 資料庫新增：新疆強迫勞動
# 資料庫新增：獨角獸
# 資料庫新增：LAND ROVER 英國
# 資料庫新增：語音
# 資料庫新增：規定
# 資料庫新增：Mac
# 資料庫新增：浙江
# 資料庫新增：Fiesta
# 資料庫新增：8891汽車
# 資料庫新增：GmbH&Co
# 資料庫新增：專利
# 資料庫新增：就業機會
# 資料庫新增：智慧座艙
# 資料庫新增：YouTube
# 資料庫新增：Duster
# 資料庫新增：Nissan Kicks
# 資料庫新增：Escape
# 資料庫新增：ST-Line
# 資料庫新增：聯發科
# 資料庫新增：崑崙巔峰版
# 資料庫新增：充電接頭
# 資料庫新增：人工智慧
# 資料庫新增：CR-V
# 資料庫新增：投資
# 資料庫新增：特仕版
# 資料庫新增：Infiniti
# 資料庫新增：自營商
# 資料庫新增：汽車運動
# 資料庫新增：LINK:EN|WP-WSJ-0000786810
# 資料庫新增：蔡淑君
# 資料庫新增：Skoda
# 資料庫新增：JEEP 美國/吉普
# 資料庫新增：i-Buzz
# 資料庫新增：蔡裕慶
# 資料庫新增：車貸
# 資料庫新增：新穎
# 資料庫新增：林口阿姨
# 資料庫新增：E-Transit
# 資料庫新增：富人
# 資料庫新增：陣營
# 資料庫新增：巴菲特死忠果粉論
# 資料庫新增：台股
# 資料庫新增：vehicle
# 資料庫新增：正新
# 資料庫新增：GT
# 資料庫新增：拒絕
# 資料庫新增：Sandero、福斯
# 資料庫新增：入門車
# 資料庫新增：SUV
# 資料庫新增：北京
# 資料庫新增：乘用
# 資料庫新增：Clio
# 資料庫新增：雲朗
# 資料庫新增：BMW
# 資料庫新增：複合成長率
# 資料庫新增：Skyline
# 資料庫新增：保時捷
# 資料庫新增：歐洲
# 資料庫新增：設計
# 資料庫新增：掀背車
# 資料庫新增：電池廠
# 資料庫新增：六和
# 資料庫新增：台灣
# 資料庫新增：GLC
# 資料庫新增：新聞
# 資料庫新增：機器人
# 資料庫新增：LEXUS
# 資料庫新增：Jeep Jeepster
# 資料庫新增：台灣新車銷售
# 資料庫新增：福斯
# 資料庫新增：冠軍
# 資料庫新增：Max Verstappen
# 資料庫新增：後驅
# 資料庫新增：Shelby Mustang Mach-E GT
# 資料庫新增：私人
# 資料庫新增：Sequoia
# 資料庫新增：Toyota Prius PHEV
# 資料庫新增：Nissan March
# 資料庫新增：概念
# 資料庫新增：光電
# 資料庫新增：改裝車廠
# 資料庫新增：油電
# 資料庫新增：連漲
# 資料庫新增：S60
# 資料庫新增：預告
# 資料庫新增：概念車
# 資料庫新增：Renauly Espace F1
# 資料庫新增：JATO
# 資料庫新增：材質
# 資料庫新增：PHEV
# 資料庫新增：Ford Tourneo Connect
# 資料庫新增：Ai
# 資料庫新增：變速箱
# 資料庫新增：Ford Focus Vignale Wagon
# 資料庫新增：大股東
# 資料庫新增：巴菲特
# 資料庫新增：浪九
# 資料庫新增：TPC
# 資料庫新增：90
# 資料庫新增：Wrangler
# 資料庫新增：電動車市場
# 資料庫新增：感測器
# 資料庫新增：黨主席
# 資料庫新增：超越車訊
# 資料庫新增：Mazda 6
# 資料庫新增：OPTIMAL
# 資料庫新增：進口車
# 資料庫新增：評價
# 資料庫新增：Lucid
# 資料庫新增：鋰價
# 資料庫新增：ALTIS
# 資料庫新增：國產
# 資料庫新增：續漲
# 資料庫新增：起亞
# 資料庫新增：正新輪胎
# 資料庫新增：量產
# 資料庫新增：Toyota RAV4
# 資料庫新增：az
# 資料庫新增：Luxgen
# 資料庫新增：碳權
# 資料庫新增：徵才
# 資料庫新增：LINK:EN|WP-WSJ-0000835398
# 資料庫新增：超微
# 資料庫新增：麗島賽車場
# 資料庫新增：旗艦
# 資料庫新增：習近平
# 資料庫新增：彭博
# 資料庫新增：鋰
# 資料庫新增：連接器
# 資料庫新增：巴菲特蘋果股票
# 資料庫新增：Auto
# 資料庫新增：Stellantis
# 資料庫新增：馬自達
# 資料庫新增：蘋果股票
# 資料庫新增：ig
# 資料庫新增：業代推薦
# 資料庫新增：啟動
# 資料庫新增：Racing
# 資料庫新增：Courier
# 資料庫新增：AC Cobra
# 資料庫新增：NACS
# 資料庫新增：工作
# 資料庫新增：阿根廷
# 資料庫新增：2020
# 資料庫新增：STS 超級房車
# 資料庫新增：AC Cobra GT Roadster
# 資料庫新增：Mokka
# 資料庫新增：駕照
# 資料庫新增：汽車影片
# 資料庫新增：Mercedes-Benz
# 資料庫新增：敞篷車
# 資料庫新增：Corolla Cross
# 資料庫新增：Peugeot 205 GTi
# 資料庫新增：Rover
# 資料庫新增：蘋果用戶
# 資料庫新增：Jet
# 資料庫新增：鈴木
# 資料庫新增：頑童MJ116
# 資料庫新增：產能
# 資料庫新增：調漲
# 資料庫新增：SKODA 捷克
# 資料庫新增：美國議員
# 資料庫新增：美銀
# 資料庫新增：創新
# 資料庫新增：Espace
# 資料庫新增：Ford Focus Wagon
# 資料庫新增：產品
# 資料庫新增：普利司通
# 資料庫新增：豐田
# 資料庫新增：最長
# 資料庫新增：5人座
# 資料庫新增：尊重人權
# 資料庫新增：充電站
# 資料庫新增：1800
# 資料庫新增：調整
# 資料庫新增：巨頭
# 資料庫新增：大數據
# 資料庫新增：Cars
# 資料庫新增：雷諾
# 資料庫新增：成長動能
# 資料庫新增：調降
# 資料庫新增：後座娛樂系統
# 資料庫新增：miami
# 資料庫新增：二手車
# 資料庫新增：客戶
# 資料庫新增：專案
# 資料庫新增：名言
# 資料庫新增：Cobra
# 資料庫新增：太空
# 資料庫新增：試車報告
# 資料庫新增：億美
# 資料庫新增：隆
# 資料庫新增：XV
# 資料庫新增：Tasman
# 資料庫新增：ModelS
# 資料庫新增：輕型商用車
# 資料庫新增：競爭力
# 資料庫新增：TOYOTA 北美/豐田
# 資料庫新增：LINK:EN|WP-WSJ-0000940377
# 資料庫新增：商標
# 資料庫新增：Fiat
# 資料庫新增：車商
# 資料庫新增：職涯
# 資料庫新增：Honda
# 資料庫新增：買車小幫手
# 資料庫新增：沙烏地阿拉伯國家石油
# 資料庫新增：柏林
# 資料庫新增：姚元浩
# 資料庫新增：雙門跑車
# 資料庫新增：情緒
# 資料庫新增：準備
# 資料庫新增：Forester
# 資料庫新增：USCBC
# 資料庫新增：Le Mans
# 資料庫新增：水泥灰
# 資料庫新增：美食
# 資料庫新增：萬輛
# 資料庫新增：功能安全
# 資料庫新增：調查
# 資料庫新增：動車
# 資料庫新增：PayPal
# 資料庫新增：EX90
# 資料庫新增：CX-9
# 資料庫新增：文化
# 資料庫新增：Vaughn Gittin Jr
# 資料庫新增：藍寶堅尼
# 資料庫新增：成為
# 資料庫新增：利潤
# 資料庫新增：Ford
# 資料庫新增：和泰汽車
# 資料庫新增：1400
# 資料庫新增：元補助
# 資料庫新增：純電
# 資料庫新增：巴士
# 資料庫新增：中衛體系
# 資料庫新增：Aston Martin
# 資料庫新增：墨西哥廠
# 資料庫新增：英國
# 資料庫新增：Raptor
# 資料庫新增：統一
# 資料庫新增：北美電
# 資料庫新增：數位鑰匙
# 資料庫新增：伺服器
# 資料庫新增：布丁狗
# 資料庫新增：國外車訊
# 資料庫新增：新車銷售
# 資料庫新增：福特汽車
# 資料庫新增：關注
# 資料庫新增：協議
# 資料庫新增：訂單
# 資料庫新增：盧比歐
# 資料庫新增：Sportage
# 資料庫新增：養車
# 資料庫新增：Wildtrak
# 資料庫新增：蘇純興
# 資料庫新增：財經
# 資料庫新增：Chevrolet
# 資料庫新增：汽車知識
# 資料庫新增：新能源
# 資料庫新增：林傳凱
# 資料庫新增：Go車誌
# 資料庫新增：Mach-E
# 資料庫新增：計畫
# 資料庫新增：Honda CR-V
# 資料庫新增：不變
# 資料庫新增：LINK:EN|WP-WSJ-0000741182
# 資料庫新增：Kicks
# 資料庫新增：Land Rover Range Rover Evoque
# 資料庫新增：SMT
# 資料庫新增：納智捷
# 資料庫新增：Ranger Thunder
# 資料庫新增：興勤
# 資料庫新增：拉抬
# 資料庫新增：剛性需求
# 資料庫新增：油價
# 資料庫新增：貝爾
# 資料庫新增：Optimer
# 資料庫新增：賽車手
# 資料庫新增：成份股
# 資料庫新增：MG4
# 資料庫新增：USPTO
# 資料庫新增：維修
# 資料庫新增：電動
# 資料庫新增：bZ4X
# 資料庫新增：手機
# 資料庫新增：飛機
# 資料庫新增：健康
# 資料庫新增：Audi
# 資料庫新增：Off-Road
# 資料庫新增：新能源車
# 資料庫新增：愛車
# 資料庫新增：Ford Focus
# 資料庫新增：碳排放
# 資料庫新增：SK On
# 資料庫新增：EV6
# 資料庫新增：資料中心
# 資料庫新增：淡水河谷
# 資料庫新增：kuga
# 資料庫新增：雪鐵龍
# 資料庫新增：Lexus
# 資料庫新增：Hypercar
# 資料庫新增：歐翼車門
# 資料庫新增：大眾汽車
# 資料庫新增：台幣
# 資料庫新增：美元
# 資料庫新增：伯恩斯
# 資料庫新增：Mitsubishi
# 資料庫新增：東莞廠
# 資料庫新增：焦點股
# 資料庫新增：補貼
# 資料庫新增：電動休旅
# 資料庫新增：Abarth
# 資料庫新增：未來
# 資料庫新增：電動車產業
# 資料庫新增：TikTok
# 資料庫新增：快時尚
# 資料庫新增：純電跑旅
# 資料庫新增：Retro
# 資料庫新增：通用
# 資料庫新增：中美
# 資料庫新增：北美充電標準
# 資料庫新增：電力
# 資料庫新增：Volkswagen
# 資料庫新增：指數
# 資料庫新增：GR Sport
# 資料庫新增：學習
# 資料庫新增：FORD 美國/福特
# 資料庫新增：motor
# 資料庫新增：跨界
# 資料庫新增：庫克
# 資料庫新增：減碳
# 資料庫新增：野馬
# 資料庫新增：有錢人
# 資料庫新增：東南亞
# 資料庫新增：PChome Online 新聞提供最新汽車新聞、人氣汽車新聞、汽車專題、汽車新聞照片、汽車新聞影片
# 資料庫新增：Pickup
# 資料庫新增：Ford Focus 5D
# 資料庫新增：格斯
# 資料庫新增：標配
# 資料庫新增：爭取
# 資料庫新增：集體評比
# 資料庫新增：車款
# 資料庫新增：MustangGT3
# 資料庫新增：玩具
# 資料庫新增：印尼
# 資料庫新增：ID4
# 資料庫新增：LUXGEN
# 資料庫新增：兩岸
# 資料庫新增：電動皮卡
# 資料庫新增：PMI
# 資料庫新增：充電樁
# 資料庫新增：福特 性能 部門 將用 Ranger Raptor T1 參加 最終 惡魔 挑戰 達卡 拉力賽
# 資料庫新增：電動機車
# 資料庫新增：國產車
# 資料庫新增：價格
# 資料庫新增：華德動能
# 資料庫新增：碳權交易
# 資料庫新增：美股
# 資料庫新增：76
# 資料庫新增：Fed
# 資料庫新增：主動安全
# 資料庫新增：先探投資週刊
# 資料庫新增：URX
# 資料庫新增：汽車配備
# 資料庫新增：Opel Mokka
# 資料庫新增：2023 STS超級房車全國系列賽 周末於麗寶賽道登場        　戰況激烈 入場穿熱褲、小可愛購票享6折優惠
# 資料庫新增：直線加速賽
# 資料庫新增：魯拉
# 資料庫新增：A11
# 資料庫新增：Volvo
# 資料庫新增：玩命關頭十、FAST X、Dodge Charger SRT Hellcat Widebody
# 資料庫新增：Altis
# 資料庫新增：大秀
# 資料庫新增：Model Y
# 資料庫新增：X-Trail
# 資料庫新增：在地
# 資料庫新增：XRT Concept
# 資料庫新增：Carroll Shelby
# 資料庫新增：SpecR汽車性能情報
# 資料庫新增：2024 Ford 福特 Mustang 野馬 RTR Spec 2 一款 全方位 視覺 變革
# 資料庫新增：Citroen
# 資料庫新增：小品牌
# 資料庫新增：LEGO
# 資料庫新增：頭條新聞
# 資料庫新增：車用電子
# 資料庫新增：增產
# 資料庫新增：汽車廠
# 資料庫新增：親子
# 資料庫新增：Mclaren
# 資料庫新增：米其林
# 資料庫新增：歐洲車市
# 資料庫新增：掛牌數
# 資料庫新增：Subaru
# 資料庫新增：超級充電站
# 資料庫新增：亮相
# 資料庫新增：友達
# 資料庫新增：車手
# 資料庫新增：2008
# 資料庫新增：最佳內裝
# 資料庫新增：交易員
# 資料庫新增：進階
# 資料庫新增：Lexus NX
# 資料庫新增：能源
# 資料庫新增：食材
# 資料庫新增：V12
# 資料庫新增：VelociRaptor
# 資料庫新增：Pick-Up
# 資料庫新增：Mitsubishi Colt Plus
# 資料庫新增：通用汽車
# 資料庫新增：L200
# 資料庫新增：結盟
# 資料庫新增：麗寶樂園
# 資料庫新增：德國福斯
# 資料庫新增：NAC
# 資料庫新增：德州
# 資料庫新增：海英俊
# 資料庫新增：XC60
# 資料庫新增：新車試駕
# 資料庫新增：綠能
# 資料庫新增：crv
# 資料庫新增：前腳
# 資料庫新增：性能
# 資料庫新增：Go好玩
# 資料庫新增：車王電
# 資料庫新增：手排
# 資料庫新增：2026年
# 資料庫新增：全時四驅
# 資料庫新增：Octavia
# 資料庫新增：HPC
# 資料庫新增：Rivian
# 資料庫新增：護照
# 資料庫新增：208
# 資料庫新增：MEB
# 資料庫新增：特斯拉
# 資料庫新增：新車安全
# 資料庫新增：滿載
# 資料庫新增：盤後
# 資料庫新增：銀行
# 資料庫新增：鏡觀車市
# 資料庫新增：馬斯克
# 資料庫新增：Taipei
# 資料庫新增：EUV
# 資料庫新增：The Taipei Times
# 資料庫新增：房車
# 資料庫新增：汽車零件廠
# 資料庫新增：週休三日
# 資料庫新增：RAV4
# 資料庫新增：急單
# 資料庫新增：FORD RANGER RAPTOR
# 資料庫新增：AI
# 資料庫新增：Apple
# 資料庫新增：美國
# 資料庫新增：重要
# 資料庫新增：比亞迪
# 資料庫新增：2022
# 資料庫新增：自駕
# 資料庫新增：製造商
# 資料庫新增：人民幣
# 資料庫新增：科技產業
# 資料庫新增：美國維吉尼亞州州長楊京
# 資料庫新增：文件
# 資料庫新增：物價
# 資料庫新增：台達電
# 資料庫新增：連假
# 資料庫新增：週休三天
# 資料庫新增：葉倫
# 資料庫新增：電動車
# 資料庫新增：淨值比
# 資料庫新增：Land
# 資料庫新增：963
# 資料庫新增：聯嘉光電
# 資料庫新增：中華電信
# 資料庫新增：電池
# 資料庫新增：大陸外交部
# 資料庫新增：Ford Mustang Mach-E GT
# 資料庫新增：合資
# 資料庫新增：法國
# 資料庫新增：歐洲銷量
# 資料庫新增：CX-5
# 資料庫新增：電動車電池
# 資料庫新增：大億
# 資料庫新增：PChome Online 新聞提供最新財經新聞、人氣財經新聞、財經專題、財經新聞照片、財經新聞影片
# 資料庫新增：蘋果
# 資料庫新增：採用
# 資料庫新增：Tesla
# 資料庫新增：Bott
# 資料庫新增：戰報
# 資料庫新增：休旅
# 資料庫新增：功能
# 資料庫新增：破產
# 資料庫新增：凱銳光電
# 資料庫新增：擴大
# 資料庫新增：區塊鏈
# 資料庫新增：Custin
# 資料庫新增：game
# 資料庫新增：續航
# 資料庫新增：三缸
# 資料庫新增：電動卡車
# 資料庫新增：營收
# 資料庫新增：軟體
# 資料庫新增：汽車產業
# 資料庫新增：科技
# 資料庫新增：越野
# 資料庫新增：Shelby
# 資料庫新增：3月
# 資料庫新增：auto
# 資料庫新增：LINK:EN|WP-WSJ-0000775990
# 資料庫新增：交通部公布臺灣新車安全評等(TNCAP)第二批二車型評等結 果 TOYOTA COROLLA ALTIS 獲得五顆星評等 HONDA CR-V 獲得三顆星評等
# 資料庫新增：海軍陸戰隊
# 資料庫新增：E-Tourneo Courier
# 資料庫新增：大型重型機車
# 資料庫新增：美企
# 資料庫新增：寧德時代
# 資料庫新增：KIA
# 資料庫新增：新車預報
# 資料庫新增：運動
# 資料庫新增：CX-60
# 資料庫新增：ADAS
# 資料庫新增：興建一座
# 資料庫新增：降價
# 資料庫新增：歐元區
# 資料庫新增：輝創電子
# 資料庫新增：Active
# 資料庫新增：LINK:EN|WP-WSJ-0000910726
# 資料庫新增：新聞報導
# 資料庫新增：T-Roc
# 資料庫新增：王國材
# 資料庫新增：美國能源部
# 資料庫新增：Puma
# 資料庫新增：國道
# 資料庫新增：FORD 澳洲/福特
# 資料庫新增：汽車美容
# 資料庫新增：Lordstown
# 資料庫新增：林傳
# 資料庫新增：越野車
# 資料庫新增：Opel Astra
# 資料庫新增：續航力
# 資料庫新增：鴻海
# 資料庫新增：華爾街
# 資料庫新增：台灣新車安全評等
# 資料庫新增：Coupe
# 資料庫新增：保險
# 資料庫新增：二手
# 資料庫新增：電動廂型車
# 資料庫新增：Ella
# 資料庫新增：永豐銀
# 資料庫新增：通膨
# 資料庫新增：台北時報
# 資料庫新增：新美齊
# 資料庫新增：奧迪
# 資料庫新增：萬美
# 資料庫新增：新聞影音
# 資料庫新增：實力
# 資料庫新增：信邦
# 資料庫新增：CCS1
# 資料庫新增：福斯汽車
# 資料庫新增：Levorg
# 資料庫新增：NX
# 資料庫新增：芭拉
# 資料庫新增：TESLA 美國
# 資料庫新增：Tiguan
# 資料庫新增：COVID-19
# 資料庫新增：鴻碩
# 資料庫新增：光寶科
# 資料庫新增：稼動率
# 資料庫新增：永續
# 資料庫新增：蔣萬安
# 資料庫新增：車聯網
# 資料庫新增：維持
# 資料庫新增：Yaris
# 資料庫新增：雲端伺服器
# 資料庫新增：自動車
# 資料庫新增：Toyota Yaris
# 資料庫新增：FOX可調式避震
# 資料庫新增：面板
# 資料庫新增：電商
# 資料庫新增：充電系統
# 資料庫新增：汽車用品
# 資料庫新增：PChome Online 新聞提供最新國際新聞、人氣國際新聞、國際專題、國際新聞照片、國際新聞影片
# 資料庫新增：社會
# 資料庫新增：車頂
# 資料庫新增：美系
# 資料庫新增：GM
# 資料庫新增：新光
# 資料庫新增：5%
# 資料庫新增：EX30
# 資料庫新增：TNCAP
# 資料庫新增：碟煞
# 資料庫新增：工業局
# 資料庫新增：試駕
# 資料庫新增：黃國
# 資料庫新增：Ig
# 資料庫新增：GT-R
# 資料庫新增：Toyota
# 資料庫新增：Dacia
# 資料庫新增：轎車
# 資料庫新增：Tourneo Courier
# 資料庫新增：Impreza
# 資料庫新增：n⁷
# 資料庫新增：2018
# 資料庫新增：太空人
# 資料庫新增：Rampage
# 資料庫新增：市場預期
# 資料庫新增：Defender
# 資料庫新增：跨界休旅車
# 資料庫新增：ETF
# 資料庫新增：Ranger
# 資料庫新增：研發
# 資料庫新增：廠商
# 資料庫新增：國泰智能電動車
# 資料庫新增：輕型機車
# 資料庫新增：汽車
# 資料庫新增：美中關係
# 資料庫新增：車用電子展
# 資料庫新增：柯受良
# 資料庫新增：商用車
# 資料庫新增：新規定
# 資料庫新增：野馬電動休旅
# 資料庫新增：促銷
# 資料庫新增：MG HS
# 資料庫新增：小春
# 資料庫新增：氣象
# 資料庫新增：Peugeot
# 資料庫新增：ford
# 資料庫新增：專訪
# 資料庫新增：前衛
# 資料庫新增：e-TNGA
# 資料庫新增：性能休旅
# 資料庫新增：商旅車
# 資料庫新增：Drive Pilot
# 資料庫新增：議員
# 資料庫新增：陸行之
# 資料庫新增：溝通
# 資料庫新增：語言
# 資料庫新增：Ford Explorer
# 資料庫新增：3馬達
# 資料庫新增：Wagon
# 資料庫新增：Nissan
# 資料庫新增：友會
# 資料庫新增：控告
# 資料庫新增：MPV
# 資料庫新增：2017
# 資料庫新增：柴油車
# 資料庫新增：內裝
# 資料庫新增：engine
# 資料庫新增：觀光
# 資料庫新增：cars
# 資料庫新增：PChome Online 新聞提供最新生活新聞、人氣生活新聞、生活專題、生活新聞照片、生活新聞影片
# 資料庫新增：總統
# 資料庫新增：FIA WEC
# 資料庫新增：預計
# 資料庫新增：物流
# 資料庫新增：車主
# 資料庫新增：Transit
# 資料庫新增：Jaguar
# 資料庫新增：貿聯-KY
# 資料庫新增：福特 SuperVan 4.2 挑戰 派克峰 賽道
# 資料庫新增：技術
# 資料庫新增：500
# 資料庫新增：聯盟
# 資料庫新增：萬轉 開頂 音爆 Gordon Murray Automotive T.33 Spider
# ----- insert_new_keywords_to_db ----- E
# ----- update_words_embeddings_to_db ----- S
# 更新：Lightning
# C:\Users\mudalse\AppData\Local\Temp\ipykernel_11488\4241739644.py:84: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   inputs = torch.tensor(input_ids)
# 更新：市占
# 更新：本田
# 更新：社群
# 更新：德國
# 更新：type:post
# 更新：訪中
# 更新：現代汽車
# 更新：car
# 更新：英國復古跑車
# 更新：日本
# 更新：菜單
# 更新：7人座
# 更新：寶馬
# 更新：電動馬達
# 更新：J1772
# 更新：BuyCarTv
# 更新：紅杉
# 更新：市佔率
# 更新：即時新聞
# 更新：嘉泥
# 更新：休旅車
# 更新：密西根州
# 更新：X
# 更新：wagon
# 更新：旅行車
# 更新：一次
# 更新：Crown
# 更新：AC
# 更新：Mitsubishi 歐洲 推出 全新 Colt 台灣 國產化 引進
# 更新：撞擊
# 更新：夏季
# 更新：RTR
# 更新：TRD
# 更新：報稅
# 更新：Chevrolet 推出 最後 一款 第六代 Camaro 紀念版 Panther
# 更新：嘉偉
# 更新：video
# 更新：Formula 1
# 更新：Roadster
# 更新：優惠
# 更新：ARTC
# 更新：體質
# 更新：長期
# 更新：Fisker
# 更新：智慧駕駛
# 更新：Ferrari
# 更新：信義新天地
# 更新：台北國際車用電子展
# 更新：美銀證券
# 更新：FORD TRANSIT XJ220
# 更新：車廠
# 更新：車
# 更新：做空機構
# 更新：Kg
# 更新：評級
# 更新：Pro
# 更新：VOLVO
# 更新：Volkswagen T-Roc
# 更新：Focus Wagon
# 更新：6000
# 更新：品牌
# 更新：suv
# 更新：大改款
# 更新：轉虧為盈
# 更新：WildtrakX
# 更新：美規
# 更新：CCS2
# 更新：Drag
# 更新：經濟衰退
# 更新：重型機車
# 更新：引擎
# 更新：CHAdeMO
# 更新：2024 Ford Mustang RTR Spec 2
# 更新：半導體
# 更新：影音系統
# 更新：2024年
# 更新：Opel
# 更新：採購副總
# 更新：投資人
# 更新：試車頻道
# 更新：蝙蝠俠機車
# 更新：Wards
# 更新：WRX Wagon
# 更新：科技類股
# 更新：Capstone
# 更新：Kuga
# 更新：空間
# 更新：三菱
# 更新：HR-V
# 更新：銷售
# 更新：專題報導
# 更新：女性墮胎權
# 更新：cat:新聞
# 更新：自行車
# 更新：Ford 正式 發佈 Mustang GT3 賽車 將於 2024 參加  Le Mans  24 小時 耐力賽
# 更新：電動車市
# 更新：地方新聞
# 更新：股價
# 更新：CX-90
# 更新：國運
# 更新：sports
# 更新：特斯拉 Cybertruck 照片 外洩 內裝 設計 細節 曝光
# 更新：Corsa
# 更新：法利
# 更新：烏俄戰爭
# 更新：Pick up
# 更新：試車影片
# 更新：薪資
# 更新：農業
# 更新：5月
# 更新：Renault
# 更新：人選
# 更新：Shell
# 更新：短缺
# 更新：汽車新聞
# 更新：紐西蘭
# 更新：Mustang Mach-E
# 更新：Hennessey
# 更新：柯有謙
# 更新：巨大
# 更新：補助
# 更新：進擊的巨人
# 更新：系統
# 更新：ModelX
# 更新：Tucson
# 更新：英業達
# 更新：撞測
# 更新：車型
# 更新：鄭顯聰
# 更新：EV
# 更新：報告
# 更新：日系
# 更新：做空
# 更新：娛樂
# 更新：焦慮
# 更新：規格
# 更新：2024
# 更新：六缸引擎
# 更新：馬丁
# 更新：Bolide
# 更新：Y
# 更新：四驅
# 更新：大眾
# 更新：法拉利
# 更新：配備
# 更新：電動休旅車
# 更新：殼牌
# 更新：瘦子
# 更新：Stormtrak
# 更新：Golf
# 更新：耐落
# 更新：順德
# 更新：儀表
# 更新：凱銳
# 更新：買車
# 更新：車訊
# 更新：消費者報告
# 更新：COROLLA
# 更新：碳中和
# 更新：全球
# 更新：MIH
# 更新：銷量
# 更新：聯準會
# 更新：MG
# 更新：XC40
# 更新：ID.7
# 更新：車王電子
# 更新：群創
# 更新：中國大陸
# 更新：Classic
# 更新：黎方國
# 更新：自動駕駛
# 更新：小七車觀點
# 更新：ESG
# 更新：TCar
# 更新：accident
# 更新：汽車討論
# 更新：VI
# 更新：Explorer
# 更新：車後座娛樂
# 更新：六度
# 更新：歐盟
# 更新：周四
# 更新：比爾
# 更新：交通
# 更新：銷售冠軍
# 更新：墮胎
# 更新：WGS矩陣分析
# 更新：進口
# 更新：小型
# 更新：FIA
# 更新：中堅企業
# 更新：第一季
# 更新：曼谷車展
# 更新：旅遊
# 更新：Ford Focus Active
# 更新：中型休旅
# 更新：套件
# 更新：Model X
# 更新：名單
# 更新：VAG
# 更新：財報
# 更新：指數基金
# 更新：福特
# 更新：蔚小理
# 更新：短軸
# 更新：Valiance
# 更新：露營
# 更新：Model C
# 更新：SAE
# 更新：經濟
# 更新：澳洲
# 更新：iPhone
# 更新：福特六和
# 更新：SYND
# 更新：Dodge
# 更新：醫師
# 更新：超級
# 更新：台電
# 更新：數位
# 更新：廢氣排放
# 更新：Mercedes
# 更新：省油
# 更新：紐約市
# 更新：電競
# 更新：PORSCHE VISION RENNDIENST
# 更新：企業
# 更新：電動車銷售
# 更新：Top Gear
# 更新：政治
# 更新：優勢
# 更新：扣留
# 更新：V8引擎
# 更新：racing
# 更新：Berlingo短軸
# 更新：柯有倫
# 更新：Sedan
# 更新：兩輪誌
# 更新：機車
# 更新：Ford Supervan
# 更新：Honda Fit
# 更新：ID3
# 更新：軟頂
# 更新：ID
# 更新：南陽實業
# 更新：麥拉倫
# 更新：Lamborghini
# 更新：台灣本田
# 更新：輪胎
# 更新：因應
# 更新：餐廳
# 更新：聯嘉
# 更新：塔科馬
# 更新：疲勞
# 更新：壓力
# 更新：Yahoo
# 更新：Bilstein
# 更新：高階
# 更新：U6
# 更新：line
# 更新：市占率
# 更新：運動休旅
# 更新：生產
# 更新：太陽能
# 更新：敞篷
# 更新：毛利率
# 更新：渦輪增壓
# 更新：外長
# 更新：預估
# 更新：插電式油電
# 更新：Super
# 更新：新聞照片
# 更新：Electric
# 更新：試車
# 更新：賽車
# 更新：LED
# 更新：標準
# 更新：員工
# 更新：HS
# 更新：分析
# 更新：侯友宜
# 更新：Ford Performance
# 更新：Leaf
# 更新：特斯拉股票
# 更新：稅收
# 更新：抵免
# 更新：體系
# 更新：下滑
# 更新：Car
# 更新：再降
# 更新：CX-70
# 更新：電動汽車
# 更新：Benz
# 更新：Jeep
# 更新：華碩
# 更新：高端
# 更新：西方
# 更新：華爾街日報
# 更新：automobiles
# 更新：Peugeot 806 Procar
# 更新：KUGA
# 更新：趨勢
# 更新：電網
# 更新：華友
# 更新：Triton
# 更新：教育
# 更新：知情人士
# 更新：北美
# 更新：TOYOTA
# 更新：3
# 更新：成長
# 更新：28
# 更新：10年
# 更新：astrA
# 更新：跨境電商
# 更新：Sandero
# 更新：Bugatti
# 更新：Bronco
# 更新：買氣
# 更新：南韓
# 更新：購車
# 更新：Cross
# 更新：林鎮
# 更新：零件
# 更新：MINI
# 更新：特斯拉股價
# 更新：飛宏
# 更新：減碳目標
# 更新：標指
# 更新：雪地
# 更新：黃金
# 更新：貨卡
# 更新：4缸
# 更新：五菱宏光
# 更新：聯邦快遞
# 更新：Cybertruck
# 更新：全球電動車
# 更新：汽油
# 更新：泰國
# 更新：VW
# 更新：提案
# 更新：賽道
# 更新：礦業
# 更新：持有
# 更新：會面
# 更新：露營車
# 更新：上海車展
# 更新：Dynamics
# 更新：地球
# 更新：LCV
# 更新：Elon Musk
# 更新：Andy
# 更新：MORGAN 英國
# 更新：通用電動車
# 更新：國事訪問
# 更新：貸款
# 更新：老爹
# 更新：展覽
# 更新：新商機
# 更新：未平倉
# 更新：Berlingo
# 更新：小三
# 更新：馬來西亞
# 更新：Mustang
# 更新：Volkswagen Golf
# 更新：ai
# 更新：供應鏈
# 更新：碳排放量
# 更新：節能
# 更新：備用電池
# 更新：Consumer reports
# 更新：巴西
# 更新：福特 推出 全新 野馬 GT4 賽車 全球 賽車 愛好者 提供 更多 選擇
# 更新：西亞
# 更新：充電
# 更新：車用晶片
# 更新：價格戰
# 更新：品質
# 更新：售價
# 更新：疫情
# 更新：Luxgen U6 Neo
# 更新：七人座
# 更新：新車
# 更新：車評
# 更新：標普
# 更新：拜登
# 更新：再生能源
# 更新：Hatch
# 更新：快充
# 更新：環保
# 更新：俄羅斯
# 更新：Bentley
# 更新：Mk
# 更新：測試
# 更新：經歷
# 更新：朱嘉偉
# 更新：東協
# 更新：MustangMach
# 更新：業績
# 更新：六福
# 更新：Heritage
# 更新：重返台灣 ！拼交車速度  6/7發表 最快6月底交車 Opel The New Astra 正式曝光！
# 更新：Tacoma
# 更新：執行長
# 更新：福特 特斯拉 達成 充電 合作 放棄 CCS1 採用 NACS
# 更新：服務
# 更新：高速公路
# 更新：影視
# 更新：IPO
# 更新：校車
# 更新：2019
# 更新：Touran
# 更新：道瓊工業指數
# 更新：配息
# 更新：週休二日
# 更新：車艙
# 更新：Line
# 更新：關鍵原料
# 更新：台灣樂高
# 更新：FORD 歐洲/福特
# 更新：V60
# 更新：交通部
# 更新：American
# 更新：Ford Kuga
# 更新：雜誌
# 更新：領牌
# 更新：TESLA
# 更新：Suzuki
# 更新：徐榛蔚
# 更新：印度
# 更新：電動車車主
# 更新：摩托車
# 更新：車用面板
# 更新：JD Power
# 更新：車市
# 更新：基金
# 更新：改款
# 更新：HONDA
# 更新：後續營運
# 更新：跨界休旅
# 更新：預測
# 更新：中國電動車
# 更新：國際
# 更新：應用材料
# 更新：muscle car
# 更新：年齡
# 更新：Hyundai
# 更新：F1
# 更新：持股
# 更新：Volvo XC60試駕
# 更新：台北
# 更新：生活
# 更新：台積電
# 更新：新一代
# 更新：電動車充電
# 更新：YARIS
# 更新：海外試駕
# 更新：現代
# 更新：庫存
# 更新：純電動車
# 更新：Lexus LM
# 更新：布林肯
# 更新：Hilux
# 更新：中國
# 更新：ID.3
# 更新：電動自行車
# 更新：Mondeo
# 更新：Aston Martin 110th Anniversary
# 更新：HYUNDAI IMAX N
# 更新：Genesis
# 更新：2023派克峰爬山賽 Ford、Alpine、Radford佳績出爐
# 更新：鎳礦
# 更新：超跑
# 更新：中華汽車
# 更新：Tremor
# 更新：銀行業
# 更新：礦商
# 更新：TOYOTA  2024 全新 Tacoma 首款 混合 動力 中型 皮卡
# 更新：跑車
# 更新：汽車價格
# 更新：消基會
# 更新：編輯精選
# 更新：太平島
# 更新：墨西哥
# 更新：改裝
# 更新：電動巴士
# 更新：沃爾瑪
# 更新：秦剛
# 更新：F-150
# 更新：特定
# 更新：TSS 3.0
# 更新：Taiwan
# 更新：Mercedes-AMG
# 更新：百度
# 更新：Google
# 更新：Ford Mustang
# 更新：Astra
# 更新：違反
# 更新：賓士
# 更新：自由開講
# 更新：人權問題
# 更新：瑪莎拉帝
# 更新：EV Pro
# 更新：Ford 準備  歐洲 推出 純電 Tourneo 車系 E-Tourneo Courier Tourneo
# 更新：ChargePoint
# 更新：中國供應鏈
# 更新：4月
# 更新：IEA
# 更新：focus
# 更新：Focus
# 更新：最新
# 更新：汽車市場
# 更新：兩年
# 更新：APEC
# 更新：PChome Online 新聞提供最新社會新聞、人氣社會新聞、社會專題、社會新聞照片、社會新聞影片
# 更新：果粉
# 更新：亞馬遜
# 更新：Model
# 更新：柴油
# 更新：蝙蝠俠
# 更新：Ferrari Daytona SP3
# 更新：今日新聞
# 更新：SYNC4
# 更新：宣德
# 更新：小改款
# 更新：Ford Mustang GT3
# 更新：GT3
# 更新：BEV
# 更新：vr
# 更新：WEC
# 更新：車展
# 更新：Hyundai Staria
# 更新：4驅
# 更新：雲端服務
# 更新：小糸
# 更新：電影
# 更新：Land Rover
# 更新：V6渦輪引擎
# 更新：保養
# 更新：AMG
# 更新：惠普
# 更新：樂高
# 更新：雙方
# 更新：Formula Drift
# 更新：車企
# 更新：皮卡
# 更新：富邦投信
# 更新：合作
# 更新：智能
# 更新：Maserati
# 更新：Ford Ranger
# 更新：ID7
# 更新：Model 3
# 更新：Porsche
# 更新：瑞銀
# 更新：大量
# 更新：Mini
# 更新：供給
# 更新：加拿大
# 更新：和泰車
# 更新：Mazda
# 更新：特仕車
# 更新：R34
# 更新：評比
# 更新：ces
# 更新：建設
# 更新：Ram
# 更新：打卡
# 更新：XC90
# 更新：機械增壓
# 更新：Audi S3 Sedan 2.0 TFSI quattro
# 更新：Crossover
# 更新：大陸
# 更新：上海
# 更新：長安福特
# 更新：華友鈷業
# 更新：渦輪
# 更新：汽車電子
# 更新：精確
# 更新：Jeepster
# 更新：FORD
# 更新：禮來
# 更新：Superb
# 更新：火山
# 更新：Red Bull
# 更新：獲得
# 更新：龍頭
# 更新：成本
# 更新：速命道
# 更新：採購
# 更新：折價
# 更新：Corolla
# 更新：ST
# 更新：EDGE
# 更新：商用車市場
# 更新：Tesla Model Y
# 更新：影音
# 更新：ID.4
# 更新：新車銷量
# 更新：敞篷跑車
# 更新：CPI
# 更新：Ford Mondeo
# 更新：旅遊業
# 更新：車控系統
# 更新：分析師
# 更新：票價
# 更新：Kia
# 更新：簽訂
# 更新：扣件
# 更新：電競筆電
# 更新：華城
# 更新：IC
# 更新：Sport
# 更新：LG
# 更新：越野機車
# 更新：劉揚偉
# 更新：新疆強迫勞動
# 更新：獨角獸
# 更新：LAND ROVER 英國
# 更新：語音
# 更新：規定
# 更新：Mac
# 更新：浙江
# 更新：Fiesta
# 更新：8891汽車
# 更新：GmbH&Co
# 更新：專利
# 更新：就業機會
# 更新：智慧座艙
# 更新：YouTube
# 更新：Duster
# 更新：Nissan Kicks
# 更新：Escape
# 更新：ST-Line
# 更新：聯發科
# 更新：崑崙巔峰版
# 更新：充電接頭
# 更新：人工智慧
# 更新：CR-V
# 更新：投資
# 更新：特仕版
# 更新：Infiniti
# 更新：自營商
# 更新：汽車運動
# 更新：LINK:EN|WP-WSJ-0000786810
# 更新：蔡淑君
# 更新：Skoda
# 更新：JEEP 美國/吉普
# 更新：i-Buzz
# 更新：蔡裕慶
# 更新：車貸
# 更新：新穎
# 更新：林口阿姨
# 更新：E-Transit
# 更新：富人
# 更新：陣營
# 更新：巴菲特死忠果粉論
# 更新：台股
# 更新：vehicle
# 更新：正新
# 更新：GT
# 更新：拒絕
# 更新：Sandero、福斯
# 更新：入門車
# 更新：SUV
# 更新：北京
# 更新：乘用
# 更新：Clio
# 更新：雲朗
# 更新：BMW
# 更新：複合成長率
# 更新：Skyline
# 更新：保時捷
# 更新：歐洲
# 更新：設計
# 更新：掀背車
# 更新：電池廠
# 更新：六和
# 更新：台灣
# 更新：GLC
# 更新：新聞
# 更新：機器人
# 更新：LEXUS
# 更新：Jeep Jeepster
# 更新：台灣新車銷售
# 更新：福斯
# 更新：冠軍
# 更新：Max Verstappen
# 更新：後驅
# 更新：Shelby Mustang Mach-E GT
# 更新：私人
# 更新：Sequoia
# 更新：Toyota Prius PHEV
# 更新：Nissan March
# 更新：概念
# 更新：光電
# 更新：改裝車廠
# 更新：油電
# 更新：連漲
# 更新：S60
# 更新：預告
# 更新：概念車
# 更新：Renauly Espace F1
# 更新：JATO
# 更新：材質
# 更新：PHEV
# 更新：Ford Tourneo Connect
# 更新：Ai
# 更新：變速箱
# 更新：Ford Focus Vignale Wagon
# 更新：大股東
# 更新：巴菲特
# 更新：浪九
# 更新：TPC
# 更新：90
# 更新：Wrangler
# 更新：電動車市場
# 更新：感測器
# 更新：黨主席
# 更新：超越車訊
# 更新：Mazda 6
# 更新：OPTIMAL
# 更新：進口車
# 更新：評價
# 更新：Lucid
# 更新：鋰價
# 更新：ALTIS
# 更新：國產
# 更新：續漲
# 更新：起亞
# 更新：正新輪胎
# 更新：量產
# 更新：Toyota RAV4
# 更新：az
# 更新：Luxgen
# 更新：碳權
# 更新：徵才
# 更新：LINK:EN|WP-WSJ-0000835398
# 更新：超微
# 更新：麗島賽車場
# 更新：旗艦
# 更新：習近平
# 更新：彭博
# 更新：鋰
# 更新：連接器
# 更新：巴菲特蘋果股票
# 更新：Auto
# 更新：Stellantis
# 更新：馬自達
# 更新：蘋果股票
# 更新：ig
# 更新：業代推薦
# 更新：啟動
# 更新：Racing
# 更新：Courier
# 更新：AC Cobra
# 更新：NACS
# 更新：工作
# 更新：阿根廷
# 更新：2020
# 更新：STS 超級房車
# 更新：AC Cobra GT Roadster
# 更新：Mokka
# 更新：駕照
# 更新：汽車影片
# 更新：Mercedes-Benz
# 更新：敞篷車
# 更新：Corolla Cross
# 更新：Peugeot 205 GTi
# 更新：Rover
# 更新：蘋果用戶
# 更新：Jet
# 更新：鈴木
# 更新：頑童MJ116
# 更新：產能
# 更新：調漲
# 更新：SKODA 捷克
# 更新：美國議員
# 更新：美銀
# 更新：創新
# 更新：Espace
# 更新：Ford Focus Wagon
# 更新：產品
# 更新：普利司通
# 更新：豐田
# 更新：最長
# 更新：5人座
# 更新：尊重人權
# 更新：充電站
# 更新：1800
# 更新：調整
# 更新：巨頭
# 更新：大數據
# 更新：Cars
# 更新：雷諾
# 更新：成長動能
# 更新：調降
# 更新：後座娛樂系統
# 更新：miami
# 更新：二手車
# 更新：客戶
# 更新：專案
# 更新：名言
# 更新：Cobra
# 更新：太空
# 更新：試車報告
# 更新：億美
# 更新：隆
# 更新：XV
# 更新：Tasman
# 更新：ModelS
# 更新：輕型商用車
# 更新：競爭力
# 更新：TOYOTA 北美/豐田
# 更新：LINK:EN|WP-WSJ-0000940377
# 更新：商標
# 更新：Fiat
# 更新：車商
# 更新：職涯
# 更新：Honda
# 更新：買車小幫手
# 更新：沙烏地阿拉伯國家石油
# 更新：柏林
# 更新：姚元浩
# 更新：雙門跑車
# 更新：情緒
# 更新：準備
# 更新：Forester
# 更新：USCBC
# 更新：Le Mans
# 更新：水泥灰
# 更新：美食
# 更新：萬輛
# 更新：功能安全
# 更新：調查
# 更新：動車
# 更新：PayPal
# 更新：EX90
# 更新：CX-9
# 更新：文化
# 更新：Vaughn Gittin Jr
# 更新：藍寶堅尼
# 更新：成為
# 更新：利潤
# 更新：Ford
# 更新：和泰汽車
# 更新：1400
# 更新：元補助
# 更新：純電
# 更新：巴士
# 更新：中衛體系
# 更新：Aston Martin
# 更新：墨西哥廠
# 更新：英國
# 更新：Raptor
# 更新：統一
# 更新：北美電
# 更新：數位鑰匙
# 更新：伺服器
# 更新：布丁狗
# 更新：國外車訊
# 更新：新車銷售
# 更新：福特汽車
# 更新：關注
# 更新：協議
# 更新：訂單
# 更新：盧比歐
# 更新：Sportage
# 更新：養車
# 更新：Wildtrak
# 更新：蘇純興
# 更新：財經
# 更新：Chevrolet
# 更新：汽車知識
# 更新：新能源
# 更新：林傳凱
# 更新：Go車誌
# 更新：Mach-E
# 更新：計畫
# 更新：Honda CR-V
# 更新：不變
# 更新：LINK:EN|WP-WSJ-0000741182
# 更新：Kicks
# 更新：Land Rover Range Rover Evoque
# 更新：SMT
# 更新：納智捷
# 更新：Ranger Thunder
# 更新：興勤
# 更新：拉抬
# 更新：剛性需求
# 更新：油價
# 更新：貝爾
# 更新：Optimer
# 更新：賽車手
# 更新：成份股
# 更新：MG4
# 更新：USPTO
# 更新：維修
# 更新：電動
# 更新：bZ4X
# 更新：手機
# 更新：飛機
# 更新：健康
# 更新：Audi
# 更新：Off-Road
# 更新：新能源車
# 更新：愛車
# 更新：Ford Focus
# 更新：碳排放
# 更新：SK On
# 更新：EV6
# 更新：資料中心
# 更新：淡水河谷
# 更新：kuga
# 更新：雪鐵龍
# 更新：Lexus
# 更新：Hypercar
# 更新：歐翼車門
# 更新：大眾汽車
# 更新：台幣
# 更新：美元
# 更新：伯恩斯
# 更新：Mitsubishi
# 更新：東莞廠
# 更新：焦點股
# 更新：補貼
# 更新：電動休旅
# 更新：Abarth
# 更新：未來
# 更新：電動車產業
# 更新：TikTok
# 更新：快時尚
# 更新：純電跑旅
# 更新：Retro
# 更新：通用
# 更新：中美
# 更新：北美充電標準
# 更新：電力
# 更新：Volkswagen
# 更新：指數
# 更新：GR Sport
# 更新：學習
# 更新：FORD 美國/福特
# 更新：motor
# 更新：跨界
# 更新：庫克
# 更新：減碳
# 更新：野馬
# 更新：有錢人
# 更新：東南亞
# 更新：PChome Online 新聞提供最新汽車新聞、人氣汽車新聞、汽車專題、汽車新聞照片、汽車新聞影片
# 更新：Pickup
# 更新：Ford Focus 5D
# 更新：格斯
# 更新：標配
# 更新：爭取
# 更新：集體評比
# 更新：車款
# 更新：MustangGT3
# 更新：玩具
# 更新：印尼
# 更新：ID4
# 更新：LUXGEN
# 更新：兩岸
# 更新：電動皮卡
# 更新：PMI
# 更新：充電樁
# 更新：福特 性能 部門 將用 Ranger Raptor T1 參加 最終 惡魔 挑戰 達卡 拉力賽
# 更新：電動機車
# 更新：國產車
# 更新：價格
# 更新：華德動能
# 更新：碳權交易
# 更新：美股
# 更新：76
# 更新：Fed
# 更新：主動安全
# 更新：先探投資週刊
# 更新：URX
# 更新：汽車配備
# 更新：Opel Mokka
# 更新：2023 STS超級房車全國系列賽 周末於麗寶賽道登場        　戰況激烈 入場穿熱褲、小可愛購票享6折優惠
# 更新：直線加速賽
# 更新：魯拉
# 更新：A11
# 更新：Volvo
# 更新：玩命關頭十、FAST X、Dodge Charger SRT Hellcat Widebody
# 更新：Altis
# 更新：大秀
# 更新：Model Y
# 更新：X-Trail
# 更新：在地
# 更新：XRT Concept
# 更新：Carroll Shelby
# 更新：SpecR汽車性能情報
# 更新：2024 Ford 福特 Mustang 野馬 RTR Spec 2 一款 全方位 視覺 變革
# 更新：Citroen
# 更新：小品牌
# 更新：LEGO
# 更新：頭條新聞
# 更新：車用電子
# 更新：增產
# 更新：汽車廠
# 更新：親子
# 更新：Mclaren
# 更新：米其林
# 更新：歐洲車市
# 更新：掛牌數
# 更新：Subaru
# 更新：超級充電站
# 更新：亮相
# 更新：友達
# 更新：車手
# 更新：2008
# 更新：最佳內裝
# 更新：交易員
# 更新：進階
# 更新：Lexus NX
# 更新：能源
# 更新：食材
# 更新：V12
# 更新：VelociRaptor
# 更新：Pick-Up
# 更新：Mitsubishi Colt Plus
# 更新：通用汽車
# 更新：L200
# 更新：結盟
# 更新：麗寶樂園
# 更新：德國福斯
# 更新：NAC
# 更新：德州
# 更新：海英俊
# 更新：XC60
# 更新：新車試駕
# 更新：綠能
# 更新：crv
# 更新：前腳
# 更新：性能
# 更新：Go好玩
# 更新：車王電
# 更新：手排
# 更新：2026年
# 更新：全時四驅
# 更新：Octavia
# 更新：HPC
# 更新：Rivian
# 更新：護照
# 更新：208
# 更新：MEB
# 更新：特斯拉
# 更新：新車安全
# 更新：滿載
# 更新：盤後
# 更新：銀行
# 更新：鏡觀車市
# 更新：馬斯克
# 更新：Taipei
# 更新：EUV
# 更新：The Taipei Times
# 更新：房車
# 更新：汽車零件廠
# 更新：週休三日
# 更新：RAV4
# 更新：急單
# 更新：FORD RANGER RAPTOR
# 更新：AI
# 更新：Apple
# 更新：美國
# 更新：重要
# 更新：比亞迪
# 更新：2022
# 更新：自駕
# 更新：製造商
# 更新：人民幣
# 更新：科技產業
# 更新：美國維吉尼亞州州長楊京
# 更新：文件
# 更新：物價
# 更新：台達電
# 更新：連假
# 更新：週休三天
# 更新：葉倫
# 更新：電動車
# 更新：淨值比
# 更新：Land
# 更新：963
# 更新：聯嘉光電
# 更新：中華電信
# 更新：電池
# 更新：大陸外交部
# 更新：Ford Mustang Mach-E GT
# 更新：合資
# 更新：法國
# 更新：歐洲銷量
# 更新：CX-5
# 更新：電動車電池
# 更新：大億
# 更新：PChome Online 新聞提供最新財經新聞、人氣財經新聞、財經專題、財經新聞照片、財經新聞影片
# 更新：蘋果
# 更新：採用
# 更新：Tesla
# 更新：Bott
# 更新：戰報
# 更新：休旅
# 更新：功能
# 更新：破產
# 更新：凱銳光電
# 更新：擴大
# 更新：區塊鏈
# 更新：Custin
# 更新：game
# 更新：續航
# 更新：三缸
# 更新：電動卡車
# 更新：營收
# 更新：軟體
# 更新：汽車產業
# 更新：科技
# 更新：越野
# 更新：Shelby
# 更新：3月
# 更新：auto
# 更新：LINK:EN|WP-WSJ-0000775990
# 更新：交通部公布臺灣新車安全評等(TNCAP)第二批二車型評等結 果 TOYOTA COROLLA ALTIS 獲得五顆星評等 HONDA CR-V 獲得三顆星評等
# 更新：海軍陸戰隊
# 更新：E-Tourneo Courier
# 更新：大型重型機車
# 更新：美企
# 更新：寧德時代
# 更新：KIA
# 更新：新車預報
# 更新：運動
# 更新：CX-60
# 更新：ADAS
# 更新：興建一座
# 更新：降價
# 更新：歐元區
# 更新：輝創電子
# 更新：Active
# 更新：LINK:EN|WP-WSJ-0000910726
# 更新：新聞報導
# 更新：T-Roc
# 更新：王國材
# 更新：美國能源部
# 更新：Puma
# 更新：國道
# 更新：FORD 澳洲/福特
# 更新：汽車美容
# 更新：Lordstown
# 更新：林傳
# 更新：越野車
# 更新：Opel Astra
# 更新：續航力
# 更新：鴻海
# 更新：華爾街
# 更新：台灣新車安全評等
# 更新：Coupe
# 更新：保險
# 更新：二手
# 更新：電動廂型車
# 更新：Ella
# 更新：永豐銀
# 更新：通膨
# 更新：台北時報
# 更新：新美齊
# 更新：奧迪
# 更新：萬美
# 更新：新聞影音
# 更新：實力
# 更新：信邦
# 更新：CCS1
# 更新：福斯汽車
# 更新：Levorg
# 更新：NX
# 更新：芭拉
# 更新：TESLA 美國
# 更新：Tiguan
# 更新：COVID-19
# 更新：鴻碩
# 更新：光寶科
# 更新：稼動率
# 更新：永續
# 更新：蔣萬安
# 更新：車聯網
# 更新：維持
# 更新：Yaris
# 更新：雲端伺服器
# 更新：自動車
# 更新：Toyota Yaris
# 更新：FOX可調式避震
# 更新：面板
# 更新：電商
# 更新：充電系統
# 更新：汽車用品
# 更新：PChome Online 新聞提供最新國際新聞、人氣國際新聞、國際專題、國際新聞照片、國際新聞影片
# 更新：社會
# 更新：車頂
# 更新：美系
# 更新：GM
# 更新：新光
# 更新：5%
# 更新：EX30
# 更新：TNCAP
# 更新：碟煞
# 更新：工業局
# 更新：試駕
# 更新：黃國
# 更新：Ig
# 更新：GT-R
# 更新：Toyota
# 更新：Dacia
# 更新：轎車
# 更新：Tourneo Courier
# 更新：Impreza
# 更新：n⁷
# 更新：2018
# 更新：太空人
# 更新：Rampage
# 更新：市場預期
# 更新：Defender
# 更新：跨界休旅車
# 更新：ETF
# 更新：Ranger
# 更新：研發
# 更新：廠商
# 更新：國泰智能電動車
# 更新：輕型機車
# 更新：汽車
# 更新：美中關係
# 更新：車用電子展
# 更新：柯受良
# 更新：商用車
# 更新：新規定
# 更新：野馬電動休旅
# 更新：促銷
# 更新：MG HS
# 更新：小春
# 更新：氣象
# 更新：Peugeot
# 更新：ford
# 更新：專訪
# 更新：前衛
# 更新：e-TNGA
# 更新：性能休旅
# 更新：商旅車
# 更新：Drive Pilot
# 更新：議員
# 更新：陸行之
# 更新：溝通
# 更新：語言
# 更新：Ford Explorer
# 更新：3馬達
# 更新：Wagon
# 更新：Nissan
# 更新：友會
# 更新：控告
# 更新：MPV
# 更新：2017
# 更新：柴油車
# 更新：內裝
# 更新：engine
# 更新：觀光
# 更新：cars
# 更新：PChome Online 新聞提供最新生活新聞、人氣生活新聞、生活專題、生活新聞照片、生活新聞影片
# 更新：總統
# 更新：FIA WEC
# 更新：預計
# 更新：物流
# 更新：車主
# 更新：Transit
# 更新：Jaguar
# 更新：貿聯-KY
# 更新：福特 SuperVan 4.2 挑戰 派克峰 賽道
# 更新：技術
# 更新：500
# 更新：聯盟
# 更新：萬轉 開頂 音爆 Gordon Murray Automotive T.33 Spider
# ----- update_words_embeddings_to_db ----- E

# %%
import sqlite3
import torch
import numpy as np
from transformers import AutoTokenizer, AutoModel
import heapq

# 初始化 tokenizer 和模型
bert = "bert-base-chinese"
chinese_tokenizer = AutoTokenizer.from_pretrained(bert)
chinese_model = AutoModel.from_pretrained(bert)

# 查詢句子
query = "外國"


# 將查詢句子轉換為模型所需的輸入張量
query_input = chinese_tokenizer(
    [query], padding=True, truncation=True, return_tensors="pt", max_length=512)
query_embedding = chinese_model(
    **query_input).last_hidden_state[:, 0, :]  # 取得 [CLS] token 的嵌入向量

# 連接到 SQLite 資料庫
connection = sqlite3.connect(db_path)

# 從資料庫中檢索嵌入向量
cursor = connection.execute("SELECT VECTORS_BART_ZH, KEYWORD FROM DATA_KEYWORDS")

# 使用最小堆維護相似度最高的前三個句子
similar_sentences = []
heap_size = 20

# 比較查詢句子和每個 CLS token 嵌入向量的相似度
for row in cursor:
    embedding_bytes = row[0]
    embedding = torch.from_numpy(np.frombuffer(
        embedding_bytes, dtype=np.float32)).unsqueeze(0)
    similarity = torch.nn.functional.cosine_similarity(
        query_embedding, embedding).item()

    # 將句子及相似度加入最小堆
    if len(similar_sentences) < heap_size:
        heapq.heappush(similar_sentences, (similarity, row[1]))
    else:
        heapq.heappushpop(similar_sentences, (similarity, row[1]))

# 關閉連接
connection.close()

# 取得前三個相似的句子及相似度
similar_sentences = sorted(similar_sentences, reverse=True)
top_similarities = [similarity for similarity, _ in similar_sentences]
top_sentences = [sentence for _, sentence in similar_sentences]

print("\n\n查詢結果如下：")
sentence_num = 0.0
is_low_similar = 0
# 列印前三個相似的句子及相似度
for similarity, sentence in zip(top_similarities, top_sentences):
    print("句子：", sentence)
    print("相似度：", similarity)
    print()
    sentence_num += 1
    is_low_similar += similarity

print(f'共{sentence_num}筆。 \n您查詢句子:\n[{query}]。\n')


# 判斷平均相似度是否偏低
similarity_need_more_then = 0.5
if sentence_num > 0 and similarity_need_more_then > (is_low_similar / sentence_num):
    print(
        f"\n注意：您的搜尋句子在資料庫中相似度偏低(平均低於{similarity_need_more_then:.2f})。")
# Out:
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertModel: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 查詢結果如下：
# 句子： 福特
# 相似度： 1.0
#
# 句子： 福斯
# 相似度： 0.9376312494277954
#
# 句子： 特斯拉
# 相似度： 0.9220630526542664
#
# 句子： 福斯汽車
# 相似度： 0.9206817150115967
#
# 句子： 福特汽車
# 相似度： 0.916707456111908
#
# 句子： 通用汽車
# 相似度： 0.9141786098480225
#
# 句子： 雪鐵龍
# 相似度： 0.9033083319664001
#
# 句子： 馬斯克
# 相似度： 0.9007899761199951
#
# 句子： 伯恩斯
# 相似度： 0.8984288573265076
#
# 句子： 法拉利
# 相似度： 0.8944268226623535
#
# 句子： 格斯
# 相似度： 0.8932355046272278
#
# 句子： 福特六和
# 相似度： 0.8931446671485901
#
# 句子： 長安福特
# 相似度： 0.8888293504714966
#
# 句子： FORD 澳洲/福特
# 相似度： 0.8855004906654358
#
# 句子： ai
# 相似度： 0.8849354982376099
#
# 句子： 比爾
# 相似度： 0.8828038573265076
#
# 句子： 瑪莎拉帝
# 相似度： 0.8806556463241577
#
# 句子： 法利
# 相似度： 0.8795092105865479
#
# 句子： car
# 相似度： 0.8793715238571167
#
# 句子： 馬丁
# 相似度： 0.8790813088417053
#
# 共20.0筆。
# 您查詢句子:
# [福特]。
